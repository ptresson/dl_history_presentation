# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_aspect('equal') 

# Draw centered axes
val = [1,0,0]
labels = ['x', 'y', 'z']
colors = ['r', 'g', 'b']
for v in range(3):
    x = [val[v-0], -val[v-0]]
    y = [val[v-1], -val[v-1]]
    z = [val[v-2], -val[v-2]]
    ax.plot(x,y,z,'dimgrey', linewidth=1)
    # ax.text(val[v-0], val[v-1], val[v-2], labels[v], color=colors[v], fontsize=20)

xcoord = [.1,
          .3,
         ]
ycoord = [.2,
         .3,
         ]
zcoord = [.5,
         .4,
         ]
labels = ["queen",
         "knight",
         ]

colors = ["steelblue",
         "darkblue",
         ]

for x, y, z, label, color in zip(xcoord, ycoord, zcoord, labels, colors):
    ax.quiver(0, 0, 0, x, y, z, color=color, lw=2, arrow_length_ratio=0.1)
    ax.text(x,y,z,label, color=color, fontsize=20)


# Hide everything else
# Hide axes ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
# make the panes transparent
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
# Hide box axes
ax._axis3don = False

# Expand to remove white space
ax.set_xlim(np.array([-1,1])*.57)
ax.set_ylim(np.array([-1,1])*.57)
ax.set_zlim(np.array([-1,1])*.57)

plt.tight_layout()
plt.savefig('attention1.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_aspect('equal') 

# Draw centered axes
val = [1,0,0]
labels = ['x', 'y', 'z']
colors = ['r', 'g', 'b']
for v in range(3):
    x = [val[v-0], -val[v-0]]
    y = [val[v-1], -val[v-1]]
    z = [val[v-2], -val[v-2]]
    ax.plot(x,y,z,'dimgrey', linewidth=1)
    # ax.text(val[v-0], val[v-1], val[v-2], labels[v], color=colors[v], fontsize=20)

xcoord = [.1,
          .3,
         ]
ycoord = [.2,
         .3,
         ]
zcoord = [.5,
         .4,
         ]
labels = ["queen",
         "knight",
         ]

colors = ["steelblue",
         "darkblue",
         ]
colorsats = ["orangered",
         "darkred",
         ]

for x, y, z, label, color, colorsat in zip(xcoord, ycoord, zcoord, labels, colors, colorsats):
    ax.quiver(0, 0, 0, x, y, z, color=color, lw=2, arrow_length_ratio=0.1, alpha=.7)
    ax.text(x,y,z,label, color=color, fontsize=20, alpha=.7)
    ax.quiver(x, y, z, -.8, .2, .1, color=colorsat, lw=2, arrow_length_ratio=0.1)
    # ax.text(x,y,z,label, color=color, fontsize=20)

ax.quiver(0, 0, 0, -.8, .2, .5, color='silver', lw=2, arrow_length_ratio=0.1)
ax.text( -.7, .2, .5,'rook', color='silver', fontsize=20, ha='right')

# Hide everything else
# Hide axes ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
# make the panes transparent
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
# Hide box axes
ax._axis3don = False

# Expand to remove white space
ax.set_xlim(np.array([-1,1])*.57)
ax.set_ylim(np.array([-1,1])*.57)
ax.set_zlim(np.array([-1,1])*.57)

plt.tight_layout()
plt.savefig('attention2.png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.set_aspect('equal') 

# Draw centered axes
val = [1,0,0]
labels = ['x', 'y', 'z']
colors = ['r', 'g', 'b']
for v in range(3):
    x = [val[v-0], -val[v-0]]
    y = [val[v-1], -val[v-1]]
    z = [val[v-2], -val[v-2]]
    ax.plot(x,y,z,'dimgrey', linewidth=1)
    # ax.text(val[v-0], val[v-1], val[v-2], labels[v], color=colors[v], fontsize=20)

xcoord = [.1,
          .3,
         ]
ycoord = [.2,
         .3,
         ]
zcoord = [.5,
         .4,
         ]
labels = ["queen",
         "knight",
         ]

colors = ["steelblue",
         "darkblue",
         ]
colorsats = ["orangered",
         "darkred",
         ]

for x, y, z, label, color, colorsat in zip(xcoord, ycoord, zcoord, labels, colors, colorsats):
    ax.quiver(0, 0, 0, x, y, z, color=color, lw=2, arrow_length_ratio=0.1, alpha=.7)
    ax.text(x,y,z,label, color=color, fontsize=20, alpha=.7)
    ax.quiver(x, y, z, .3, -.6, -.8, color=colorsat, lw=2, arrow_length_ratio=0.1)
    # ax.text(x,y,z,label, color=color, fontsize=20)

ax.quiver(0, 0, 0, .7, -.5, -.5, color='silver', lw=2, arrow_length_ratio=0.1)
ax.text( .7, -.5, -.5,'UK', color='silver', fontsize=20, ha='left')

# Hide everything else
# Hide axes ticks
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
# make the panes transparent
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
# Hide box axes
ax._axis3don = False

# Expand to remove white space
ax.set_xlim(np.array([-1,1])*.57)
ax.set_ylim(np.array([-1,1])*.57)
ax.set_zlim(np.array([-1,1])*.57)

plt.tight_layout()
plt.savefig('attention3.png')
plt.show()
